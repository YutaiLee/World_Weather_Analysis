# %% [markdown]
# ## Deliverable 1

# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 754

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | mahebourg
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | klaksvik
# Processing Record 6 of Set 1 | umzimvubu
# City not found. Skipping
# Processing Record 7 of Set 1 | tasiilaq
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | zelenoborskiy
# Processing Record 10 of Set 1 | irtyshskiy
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | cabo san lucas
# Processing Record 13 of Set 1 | barrow
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 15 of Set 1 | dhidhdhoo
# Processing Record 16 of Set 1 | gashua
# Processing Record 17 of Set 1 | khatanga
# Processing Record 18 of Set 1 | sabha
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | marawi
# Processing Record 21 of Set 1 | chuy
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | kurmanayevka
# Processing Record 24 of Set 1 | ancud
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | copperas cove
# Processing Record 29 of Set 1 | panlaitan
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | ijaki
# City not found. Skipping
# Processing Record 32 of Set 1 | afua
# Processing Record 33 of Set 1 | lata
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | albany
# Processing Record 36 of Set 1 | poum
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | puerto del rosario
# Processing Record 39 of Set 1 | severo-kurilsk
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | clyde river
# Processing Record 42 of Set 1 | souillac
# Processing Record 43 of Set 1 | mao
# Processing Record 44 of Set 1 | chokurdakh
# Processing Record 45 of Set 1 | maghama
# City not found. Skipping
# Processing Record 46 of Set 1 | saint george
# Processing Record 47 of Set 1 | tuatapere
# Processing Record 48 of Set 1 | nikolskoye
# Processing Record 49 of Set 1 | dubbo
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | morondava
# Processing Record 2 of Set 2 | rusne
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | bambous virieux
# Processing Record 5 of Set 2 | nanortalik
# Processing Record 6 of Set 2 | gorontalo
# Processing Record 7 of Set 2 | keflavik
# Processing Record 8 of Set 2 | castro
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | baykit
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | bandarbeyla
# Processing Record 14 of Set 2 | waingapu
# Processing Record 15 of Set 2 | luderitz
# Processing Record 16 of Set 2 | gudari
# Processing Record 17 of Set 2 | pascagoula
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | tsihombe
# City not found. Skipping
# Processing Record 20 of Set 2 | barhiya
# Processing Record 21 of Set 2 | lebu
# Processing Record 22 of Set 2 | carnarvon
# Processing Record 23 of Set 2 | kapaa
# Processing Record 24 of Set 2 | ixtapa
# Processing Record 25 of Set 2 | benguela
# Processing Record 26 of Set 2 | harstad
# Processing Record 27 of Set 2 | boralday
# Processing Record 28 of Set 2 | pevek
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping
# Processing Record 30 of Set 2 | raudeberg
# Processing Record 31 of Set 2 | turka
# Processing Record 32 of Set 2 | belmonte
# Processing Record 33 of Set 2 | terney
# Processing Record 34 of Set 2 | narsaq
# Processing Record 35 of Set 2 | vestmanna
# Processing Record 36 of Set 2 | kirakira
# Processing Record 37 of Set 2 | provideniya
# Processing Record 38 of Set 2 | nizhneyansk
# City not found. Skipping
# Processing Record 39 of Set 2 | bubaque
# Processing Record 40 of Set 2 | wangaratta
# Processing Record 41 of Set 2 | parabel
# Processing Record 42 of Set 2 | ivankiv
# Processing Record 43 of Set 2 | priladozhskiy
# Processing Record 44 of Set 2 | hermanus
# Processing Record 45 of Set 2 | bilibino
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | catumbela
# Processing Record 49 of Set 2 | klamath falls
# Processing Record 50 of Set 2 | san luis
# Processing Record 1 of Set 3 | vila do maio
# Processing Record 2 of Set 3 | bonthe
# Processing Record 3 of Set 3 | bridlington
# Processing Record 4 of Set 3 | upernavik
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | bundaberg
# Processing Record 7 of Set 3 | sao filipe
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | apostolove
# Processing Record 11 of Set 3 | maldonado
# Processing Record 12 of Set 3 | richards bay
# Processing Record 13 of Set 3 | prata
# Processing Record 14 of Set 3 | warri
# Processing Record 15 of Set 3 | high level
# Processing Record 16 of Set 3 | songea
# Processing Record 17 of Set 3 | longyearbyen
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | san quintin
# Processing Record 20 of Set 3 | iqaluit
# Processing Record 21 of Set 3 | amderma
# City not found. Skipping
# Processing Record 22 of Set 3 | mys shmidta
# City not found. Skipping
# Processing Record 23 of Set 3 | dehloran
# Processing Record 24 of Set 3 | amapa
# Processing Record 25 of Set 3 | bulungu
# Processing Record 26 of Set 3 | iranshahr
# Processing Record 27 of Set 3 | alyangula
# Processing Record 28 of Set 3 | mecca
# Processing Record 29 of Set 3 | kathmandu
# Processing Record 30 of Set 3 | torbay
# Processing Record 31 of Set 3 | lavrentiya
# Processing Record 32 of Set 3 | tondano
# Processing Record 33 of Set 3 | vila franca do campo
# Processing Record 34 of Set 3 | panaba
# Processing Record 35 of Set 3 | ayagoz
# Processing Record 36 of Set 3 | metu
# Processing Record 37 of Set 3 | pombas
# Processing Record 38 of Set 3 | new norfolk
# Processing Record 39 of Set 3 | dalvik
# Processing Record 40 of Set 3 | dikson
# Processing Record 41 of Set 3 | singaraja
# Processing Record 42 of Set 3 | castres
# Processing Record 43 of Set 3 | suez
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | la reforma
# Processing Record 46 of Set 3 | coihaique
# Processing Record 47 of Set 3 | lorengau
# Processing Record 48 of Set 3 | bintulu
# Processing Record 49 of Set 3 | kaitangata
# Processing Record 50 of Set 3 | swakopmund
# Processing Record 1 of Set 4 | kucura
# Processing Record 2 of Set 4 | gobabis
# Processing Record 3 of Set 4 | hobart
# Processing Record 4 of Set 4 | puerto madryn
# Processing Record 5 of Set 4 | katsuura
# Processing Record 6 of Set 4 | nemuro
# Processing Record 7 of Set 4 | andros town
# Processing Record 8 of Set 4 | vardo
# Processing Record 9 of Set 4 | talnakh
# Processing Record 10 of Set 4 | atbasar
# Processing Record 11 of Set 4 | longlac
# City not found. Skipping
# Processing Record 12 of Set 4 | ilulissat
# Processing Record 13 of Set 4 | touros
# Processing Record 14 of Set 4 | gat
# Processing Record 15 of Set 4 | qaqortoq
# Processing Record 16 of Set 4 | longyan
# Processing Record 17 of Set 4 | kholmogory
# Processing Record 18 of Set 4 | lima
# Processing Record 19 of Set 4 | romitan
# Processing Record 20 of Set 4 | norman wells
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | butaritari
# Processing Record 23 of Set 4 | pangody
# Processing Record 24 of Set 4 | laguna
# Processing Record 25 of Set 4 | myitkyina
# Processing Record 26 of Set 4 | marcona
# City not found. Skipping
# Processing Record 27 of Set 4 | abbeville
# Processing Record 28 of Set 4 | nador
# Processing Record 29 of Set 4 | mokhsogollokh
# Processing Record 30 of Set 4 | el paujil
# Processing Record 31 of Set 4 | rawson
# Processing Record 32 of Set 4 | preobrazheniye
# Processing Record 33 of Set 4 | karamay
# City not found. Skipping
# Processing Record 34 of Set 4 | aklavik
# Processing Record 35 of Set 4 | eyl
# Processing Record 36 of Set 4 | tarakan
# Processing Record 37 of Set 4 | praia
# Processing Record 38 of Set 4 | puerto quijarro
# Processing Record 39 of Set 4 | lourdes
# Processing Record 40 of Set 4 | tuktoyaktuk
# Processing Record 41 of Set 4 | victoria
# Processing Record 42 of Set 4 | hasaki
# Processing Record 43 of Set 4 | padang
# Processing Record 44 of Set 4 | saleaula
# City not found. Skipping
# Processing Record 45 of Set 4 | fare
# Processing Record 46 of Set 4 | arraial do cabo
# Processing Record 47 of Set 4 | ust-omchug
# Processing Record 48 of Set 4 | nguiu
# City not found. Skipping
# Processing Record 49 of Set 4 | port lincoln
# Processing Record 50 of Set 4 | geraldton
# Processing Record 1 of Set 5 | khandbari
# Processing Record 2 of Set 5 | katrineholm
# Processing Record 3 of Set 5 | lasa
# Processing Record 4 of Set 5 | xingtai
# Processing Record 5 of Set 5 | boat of garten
# Processing Record 6 of Set 5 | lolua
# City not found. Skipping
# Processing Record 7 of Set 5 | saldanha
# Processing Record 8 of Set 5 | karratha
# Processing Record 9 of Set 5 | coquimbo
# Processing Record 10 of Set 5 | wellington
# Processing Record 11 of Set 5 | belushya guba
# City not found. Skipping
# Processing Record 12 of Set 5 | kuching
# Processing Record 13 of Set 5 | darovskoy
# Processing Record 14 of Set 5 | kebumen
# Processing Record 15 of Set 5 | baihar
# Processing Record 16 of Set 5 | carutapera
# Processing Record 17 of Set 5 | vao
# Processing Record 18 of Set 5 | kruisfontein
# Processing Record 19 of Set 5 | araouane
# Processing Record 20 of Set 5 | udachnyy
# Processing Record 21 of Set 5 | lentekhi
# Processing Record 22 of Set 5 | shimanovsk
# Processing Record 23 of Set 5 | sentyabrskiy
# City not found. Skipping
# Processing Record 24 of Set 5 | port hedland
# Processing Record 25 of Set 5 | tomatlan
# Processing Record 26 of Set 5 | la ronge
# Processing Record 27 of Set 5 | boguchany
# Processing Record 28 of Set 5 | surt
# Processing Record 29 of Set 5 | pemangkat
# Processing Record 30 of Set 5 | yaypan
# Processing Record 31 of Set 5 | xining
# Processing Record 32 of Set 5 | samusu
# City not found. Skipping
# Processing Record 33 of Set 5 | galveston
# Processing Record 34 of Set 5 | starotimoshkino
# Processing Record 35 of Set 5 | bakonyszentlaszlo
# Processing Record 36 of Set 5 | halalo
# City not found. Skipping
# Processing Record 37 of Set 5 | ruatoria
# City not found. Skipping
# Processing Record 38 of Set 5 | atchison
# Processing Record 39 of Set 5 | odesskoye
# Processing Record 40 of Set 5 | natal
# Processing Record 41 of Set 5 | junction city
# Processing Record 42 of Set 5 | airai
# Processing Record 43 of Set 5 | gamba
# Processing Record 44 of Set 5 | kalakamati
# Processing Record 45 of Set 5 | nanma
# Processing Record 46 of Set 5 | vermilion
# Processing Record 47 of Set 5 | luganville
# Processing Record 48 of Set 5 | grand gaube
# Processing Record 49 of Set 5 | saint-philippe
# Processing Record 50 of Set 5 | shahdadkot
# Processing Record 1 of Set 6 | kodiak
# Processing Record 2 of Set 6 | santa cruz
# Processing Record 3 of Set 6 | shenjiamen
# Processing Record 4 of Set 6 | yining
# Processing Record 5 of Set 6 | general roca
# Processing Record 6 of Set 6 | la paz
# Processing Record 7 of Set 6 | juan lacaze
# Processing Record 8 of Set 6 | faya
# Processing Record 9 of Set 6 | doha
# Processing Record 10 of Set 6 | lidzbark warminski
# Processing Record 11 of Set 6 | meulaboh
# Processing Record 12 of Set 6 | krasnoarmeysk
# Processing Record 13 of Set 6 | vestmannaeyjar
# Processing Record 14 of Set 6 | lake city
# Processing Record 15 of Set 6 | lakes entrance
# Processing Record 16 of Set 6 | jining
# Processing Record 17 of Set 6 | apt
# Processing Record 18 of Set 6 | khanu woralaksaburi
# Processing Record 19 of Set 6 | jalu
# Processing Record 20 of Set 6 | tiruvottiyur
# City not found. Skipping
# Processing Record 21 of Set 6 | kalmunai
# Processing Record 22 of Set 6 | sao joao da barra
# Processing Record 23 of Set 6 | coswig
# Processing Record 24 of Set 6 | east london
# Processing Record 25 of Set 6 | tura
# Processing Record 26 of Set 6 | dalbandin
# Processing Record 27 of Set 6 | rungata
# City not found. Skipping
# Processing Record 28 of Set 6 | san diego de los banos
# Processing Record 29 of Set 6 | kavieng
# Processing Record 30 of Set 6 | grand river south east
# City not found. Skipping
# Processing Record 31 of Set 6 | guarapari
# Processing Record 32 of Set 6 | belyy yar
# Processing Record 33 of Set 6 | burica
# City not found. Skipping
# Processing Record 34 of Set 6 | husavik
# Processing Record 35 of Set 6 | kaura namoda
# Processing Record 36 of Set 6 | badarwas
# Processing Record 37 of Set 6 | rocha
# Processing Record 38 of Set 6 | kuche
# City not found. Skipping
# Processing Record 39 of Set 6 | san patricio
# Processing Record 40 of Set 6 | kimbe
# Processing Record 41 of Set 6 | masuda
# Processing Record 42 of Set 6 | byron bay
# Processing Record 43 of Set 6 | christchurch
# Processing Record 44 of Set 6 | kavaratti
# Processing Record 45 of Set 6 | mangrol
# Processing Record 46 of Set 6 | mweka
# Processing Record 47 of Set 6 | alugan
# Processing Record 48 of Set 6 | faanui
# Processing Record 49 of Set 6 | barentsburg
# City not found. Skipping
# Processing Record 50 of Set 6 | svetlogorsk
# Processing Record 1 of Set 7 | clonakilty
# Processing Record 2 of Set 7 | imeni poliny osipenko
# Processing Record 3 of Set 7 | goderich
# Processing Record 4 of Set 7 | flinders
# Processing Record 5 of Set 7 | alofi
# Processing Record 6 of Set 7 | hambantota
# Processing Record 7 of Set 7 | sitka
# Processing Record 8 of Set 7 | esperance
# Processing Record 9 of Set 7 | sapa
# Processing Record 10 of Set 7 | ukiah
# Processing Record 11 of Set 7 | krasnovishersk
# Processing Record 12 of Set 7 | ta khmau
# Processing Record 13 of Set 7 | sorvag
# City not found. Skipping
# Processing Record 14 of Set 7 | cristesti
# Processing Record 15 of Set 7 | payo
# Processing Record 16 of Set 7 | samarai
# Processing Record 17 of Set 7 | ambositra
# Processing Record 18 of Set 7 | leningradskiy
# Processing Record 19 of Set 7 | attawapiskat
# City not found. Skipping
# Processing Record 20 of Set 7 | caravelas
# Processing Record 21 of Set 7 | kutum
# Processing Record 22 of Set 7 | mutsamudu
# City not found. Skipping
# Processing Record 23 of Set 7 | paamiut
# Processing Record 24 of Set 7 | hobyo
# Processing Record 25 of Set 7 | tangwani
# Processing Record 26 of Set 7 | pierre
# Processing Record 27 of Set 7 | pacific grove
# Processing Record 28 of Set 7 | birjand
# Processing Record 29 of Set 7 | yei
# Processing Record 30 of Set 7 | east foothills
# Processing Record 31 of Set 7 | tocopilla
# Processing Record 32 of Set 7 | sembe
# Processing Record 33 of Set 7 | beringovskiy
# Processing Record 34 of Set 7 | boz
# Processing Record 35 of Set 7 | muros
# Processing Record 36 of Set 7 | fort erie
# Processing Record 37 of Set 7 | tezu
# Processing Record 38 of Set 7 | pisco
# Processing Record 39 of Set 7 | ballina
# Processing Record 40 of Set 7 | los llanos de aridane
# Processing Record 41 of Set 7 | hengshui
# Processing Record 42 of Set 7 | daugavpils
# Processing Record 43 of Set 7 | aksarka
# Processing Record 44 of Set 7 | mayo
# Processing Record 45 of Set 7 | vaitupu
# City not found. Skipping
# Processing Record 46 of Set 7 | fortuna
# Processing Record 47 of Set 7 | namibe
# Processing Record 48 of Set 7 | berlevag
# Processing Record 49 of Set 7 | bardiyah
# Processing Record 50 of Set 7 | bull savanna
# Processing Record 1 of Set 8 | cherskiy
# Processing Record 2 of Set 8 | codrington
# Processing Record 3 of Set 8 | mackenzie
# Processing Record 4 of Set 8 | benjamin constant
# Processing Record 5 of Set 8 | avera
# Processing Record 6 of Set 8 | goba
# Processing Record 7 of Set 8 | penzance
# Processing Record 8 of Set 8 | margate
# Processing Record 9 of Set 8 | semirara
# Processing Record 10 of Set 8 | wuwei
# Processing Record 11 of Set 8 | ulkan
# Processing Record 12 of Set 8 | lisburn
# Processing Record 13 of Set 8 | ola
# Processing Record 14 of Set 8 | northam
# Processing Record 15 of Set 8 | ksenyevka
# City not found. Skipping
# Processing Record 16 of Set 8 | praia da vitoria
# Processing Record 17 of Set 8 | adjumani
# Processing Record 18 of Set 8 | pontal do parana
# Processing Record 19 of Set 8 | zhigansk
# Processing Record 20 of Set 8 | lompoc
# Processing Record 21 of Set 8 | rheden
# Processing Record 22 of Set 8 | buta
# Processing Record 23 of Set 8 | daru
# Processing Record 24 of Set 8 | sao jose da coroa grande
# Processing Record 25 of Set 8 | tevaitoa
# Processing Record 26 of Set 8 | novikovo
# Processing Record 27 of Set 8 | lugovskiy
# City not found. Skipping
# Processing Record 28 of Set 8 | sao miguel do araguaia
# Processing Record 29 of Set 8 | dubna
# Processing Record 30 of Set 8 | besikduzu
# Processing Record 31 of Set 8 | kharp
# Processing Record 32 of Set 8 | utica
# Processing Record 33 of Set 8 | lincoln
# Processing Record 34 of Set 8 | ocampo
# Processing Record 35 of Set 8 | requena
# Processing Record 36 of Set 8 | russell
# Processing Record 37 of Set 8 | belle fourche
# Processing Record 38 of Set 8 | pangnirtung
# Processing Record 39 of Set 8 | port jervis
# Processing Record 40 of Set 8 | chapais
# Processing Record 41 of Set 8 | stokmarknes
# Processing Record 42 of Set 8 | ituiutaba
# Processing Record 43 of Set 8 | waipawa
# Processing Record 44 of Set 8 | sobolevo
# Processing Record 45 of Set 8 | mogocha
# Processing Record 46 of Set 8 | broken hill
# Processing Record 47 of Set 8 | vuktyl
# Processing Record 48 of Set 8 | san joaquin
# Processing Record 49 of Set 8 | halifax
# Processing Record 50 of Set 8 | kargapolye
# City not found. Skipping
# Processing Record 1 of Set 9 | maymyo
# Processing Record 2 of Set 9 | tautira
# Processing Record 3 of Set 9 | polyarnyye zori
# Processing Record 4 of Set 9 | tokmak
# Processing Record 5 of Set 9 | saint-augustin
# Processing Record 6 of Set 9 | sechura
# Processing Record 7 of Set 9 | quimper
# Processing Record 8 of Set 9 | mehamn
# Processing Record 9 of Set 9 | kamenka
# Processing Record 10 of Set 9 | bouca
# Processing Record 11 of Set 9 | bontang
# Processing Record 12 of Set 9 | port-gentil
# Processing Record 13 of Set 9 | baijiantan
# Processing Record 14 of Set 9 | sena madureira
# Processing Record 15 of Set 9 | yulara
# Processing Record 16 of Set 9 | comodoro rivadavia
# Processing Record 17 of Set 9 | markova
# Processing Record 18 of Set 9 | mariinsk
# Processing Record 19 of Set 9 | wonthaggi
# Processing Record 20 of Set 9 | carnot
# Processing Record 21 of Set 9 | shimoda
# Processing Record 22 of Set 9 | olafsvik
# Processing Record 23 of Set 9 | auki
# Processing Record 24 of Set 9 | kahului
# Processing Record 25 of Set 9 | bengkulu
# Processing Record 26 of Set 9 | mahibadhoo
# Processing Record 27 of Set 9 | mocambique
# City not found. Skipping
# Processing Record 28 of Set 9 | marzuq
# Processing Record 29 of Set 9 | port hardy
# Processing Record 30 of Set 9 | yako
# Processing Record 31 of Set 9 | chipinge
# Processing Record 32 of Set 9 | moses lake
# Processing Record 33 of Set 9 | kaputa
# Processing Record 34 of Set 9 | saint-joseph
# Processing Record 35 of Set 9 | hihifo
# City not found. Skipping
# Processing Record 36 of Set 9 | mirador
# Processing Record 37 of Set 9 | mazamari
# Processing Record 38 of Set 9 | bullingen
# City not found. Skipping
# Processing Record 39 of Set 9 | te anau
# Processing Record 40 of Set 9 | mazagao
# Processing Record 41 of Set 9 | hualmay
# Processing Record 42 of Set 9 | vagur
# Processing Record 43 of Set 9 | pangai
# Processing Record 44 of Set 9 | cayenne
# Processing Record 45 of Set 9 | fukue
# Processing Record 46 of Set 9 | wembley
# Processing Record 47 of Set 9 | snezhnogorsk
# Processing Record 48 of Set 9 | jiuquan
# Processing Record 49 of Set 9 | zyryanka
# Processing Record 50 of Set 9 | moyobamba
# Processing Record 1 of Set 10 | north bend
# Processing Record 2 of Set 10 | hofn
# Processing Record 3 of Set 10 | amarante do maranhao
# Processing Record 4 of Set 10 | portland
# Processing Record 5 of Set 10 | mount pleasant
# Processing Record 6 of Set 10 | burkhala
# City not found. Skipping
# Processing Record 7 of Set 10 | sungaipenuh
# Processing Record 8 of Set 10 | shaowu
# Processing Record 9 of Set 10 | paramonga
# Processing Record 10 of Set 10 | saurimo
# Processing Record 11 of Set 10 | saryshagan
# City not found. Skipping
# Processing Record 12 of Set 10 | tiznit
# Processing Record 13 of Set 10 | bara
# Processing Record 14 of Set 10 | marsh harbour
# Processing Record 15 of Set 10 | sisimiut
# Processing Record 16 of Set 10 | mayumba
# Processing Record 17 of Set 10 | bjorkelangen
# Processing Record 18 of Set 10 | sorland
# Processing Record 19 of Set 10 | hit
# Processing Record 20 of Set 10 | lykhivka
# Processing Record 21 of Set 10 | kalispell
# Processing Record 22 of Set 10 | merrill
# Processing Record 23 of Set 10 | nouadhibou
# Processing Record 24 of Set 10 | ketchikan
# Processing Record 25 of Set 10 | tumannyy
# City not found. Skipping
# Processing Record 26 of Set 10 | bone
# Processing Record 27 of Set 10 | popondetta
# Processing Record 28 of Set 10 | lazaro cardenas
# Processing Record 29 of Set 10 | itoman
# Processing Record 30 of Set 10 | buqayq
# City not found. Skipping
# Processing Record 31 of Set 10 | khromtau
# Processing Record 32 of Set 10 | bella union
# Processing Record 33 of Set 10 | listvyanskiy
# Processing Record 34 of Set 10 | puerto carreno
# Processing Record 35 of Set 10 | hervey bay
# Processing Record 36 of Set 10 | fort abbas
# Processing Record 37 of Set 10 | bargal
# City not found. Skipping
# Processing Record 38 of Set 10 | kiunga
# Processing Record 39 of Set 10 | progreso
# Processing Record 40 of Set 10 | rafaela
# Processing Record 41 of Set 10 | cabedelo
# Processing Record 42 of Set 10 | telenesti
# Processing Record 43 of Set 10 | porto novo
# Processing Record 44 of Set 10 | oshakati
# Processing Record 45 of Set 10 | olenino
# Processing Record 46 of Set 10 | joshimath
# Processing Record 47 of Set 10 | theunissen
# Processing Record 48 of Set 10 | isangel
# Processing Record 49 of Set 10 | san cristobal
# Processing Record 50 of Set 10 | leibnitz
# Processing Record 1 of Set 11 | kjollefjord
# Processing Record 2 of Set 11 | moron
# Processing Record 3 of Set 11 | moustheni
# Processing Record 4 of Set 11 | flin flon
# Processing Record 5 of Set 11 | arlit
# Processing Record 6 of Set 11 | ust-kamchatsk
# City not found. Skipping
# Processing Record 7 of Set 11 | cap malheureux
# Processing Record 8 of Set 11 | kiama
# Processing Record 9 of Set 11 | gwadar
# Processing Record 10 of Set 11 | san antonio
# Processing Record 11 of Set 11 | ngukurr
# City not found. Skipping
# Processing Record 12 of Set 11 | kaeo
# Processing Record 13 of Set 11 | bilma
# Processing Record 14 of Set 11 | egvekinot
# Processing Record 15 of Set 11 | ngunguru
# Processing Record 16 of Set 11 | shingu
# Processing Record 17 of Set 11 | kysyl-syr
# Processing Record 18 of Set 11 | russellville
# Processing Record 19 of Set 11 | aksu
# Processing Record 20 of Set 11 | qesarya
# Processing Record 21 of Set 11 | craig
# Processing Record 22 of Set 11 | dunedin
# Processing Record 23 of Set 11 | morgan city
# Processing Record 24 of Set 11 | qui nhon
# Processing Record 25 of Set 11 | kidal
# Processing Record 26 of Set 11 | knysna
# Processing Record 27 of Set 11 | okhotsk
# Processing Record 28 of Set 11 | seguin
# Processing Record 29 of Set 11 | santa marta
# Processing Record 30 of Set 11 | mantua
# Processing Record 31 of Set 11 | lodja
# Processing Record 32 of Set 11 | nagorsk
# Processing Record 33 of Set 11 | mount isa
# Processing Record 34 of Set 11 | kualakapuas
# Processing Record 35 of Set 11 | weihai
# Processing Record 36 of Set 11 | yakeshi
# Processing Record 37 of Set 11 | thompson
# Processing Record 38 of Set 11 | hirara
# Processing Record 39 of Set 11 | sambava
# Processing Record 40 of Set 11 | bathsheba
# Processing Record 41 of Set 11 | songjianghe
# Processing Record 42 of Set 11 | sarakhs
# Processing Record 43 of Set 11 | semikarakorsk
# Processing Record 44 of Set 11 | ericeira
# Processing Record 45 of Set 11 | fairbanks
# Processing Record 46 of Set 11 | ostrovnoy
# Processing Record 47 of Set 11 | ouargaye
# Processing Record 48 of Set 11 | teya
# Processing Record 49 of Set 11 | oriximina
# Processing Record 50 of Set 11 | socorro
# Processing Record 1 of Set 12 | lufilufi
# Processing Record 2 of Set 12 | juneau
# Processing Record 3 of Set 12 | los algarrobos
# Processing Record 4 of Set 12 | ucluelet
# Processing Record 5 of Set 12 | christiana
# Processing Record 6 of Set 12 | kieta
# Processing Record 7 of Set 12 | kapit
# Processing Record 8 of Set 12 | port blair
# Processing Record 9 of Set 12 | taoudenni
# Processing Record 10 of Set 12 | mishelevka
# Processing Record 11 of Set 12 | sao sebastiao
# Processing Record 12 of Set 12 | conde
# Processing Record 13 of Set 12 | katobu
# Processing Record 14 of Set 12 | knyaginino
# Processing Record 15 of Set 12 | yueyang
# Processing Record 16 of Set 12 | nizhnevartovsk
# Processing Record 17 of Set 12 | wagga wagga
# Processing Record 18 of Set 12 | gurgan
# City not found. Skipping
# Processing Record 19 of Set 12 | gondanglegi
# Processing Record 20 of Set 12 | charters towers
# Processing Record 21 of Set 12 | seydi
# Processing Record 22 of Set 12 | campoverde
# Processing Record 23 of Set 12 | ozimek
# Processing Record 24 of Set 12 | gorno-altaysk
# Processing Record 25 of Set 12 | shediac
# Processing Record 26 of Set 12 | arrecife
# Processing Record 27 of Set 12 | phan thiet
# Processing Record 28 of Set 12 | ayorou
# Processing Record 29 of Set 12 | jurm
# Processing Record 30 of Set 12 | yithion
# City not found. Skipping
# Processing Record 31 of Set 12 | wakkanai
# Processing Record 32 of Set 12 | alcala de henares
# Processing Record 33 of Set 12 | nushki
# Processing Record 34 of Set 12 | recas
# Processing Record 35 of Set 12 | magway
# Processing Record 36 of Set 12 | shenxian
# Processing Record 37 of Set 12 | dicabisagan
# Processing Record 38 of Set 12 | mount gambier
# Processing Record 39 of Set 12 | uporovo
# Processing Record 40 of Set 12 | sakaiminato
# Processing Record 41 of Set 12 | bambanglipuro
# Processing Record 42 of Set 12 | maltahohe
# Processing Record 43 of Set 12 | champerico
# Processing Record 44 of Set 12 | ingham
# Processing Record 45 of Set 12 | mersing
# Processing Record 46 of Set 12 | emba
# Processing Record 47 of Set 12 | henties bay
# Processing Record 48 of Set 12 | naze
# Processing Record 49 of Set 12 | pringsewu
# Processing Record 50 of Set 12 | iberia
# Processing Record 1 of Set 13 | nyurba
# Processing Record 2 of Set 13 | yamethin
# Processing Record 3 of Set 13 | constitucion
# Processing Record 4 of Set 13 | yar-sale
# Processing Record 5 of Set 13 | pendra
# Processing Record 6 of Set 13 | zabol
# Processing Record 7 of Set 13 | yenagoa
# Processing Record 8 of Set 13 | sumbawa
# City not found. Skipping
# Processing Record 9 of Set 13 | kasongo-lunda
# Processing Record 10 of Set 13 | quang ngai
# Processing Record 11 of Set 13 | kampene
# Processing Record 12 of Set 13 | san juan
# Processing Record 13 of Set 13 | jiangyou
# Processing Record 14 of Set 13 | watsa
# Processing Record 15 of Set 13 | santa lucia
# Processing Record 16 of Set 13 | masaurhi
# Processing Record 17 of Set 13 | black diamond
# Processing Record 18 of Set 13 | srednekolymsk
# Processing Record 19 of Set 13 | gravdal
# Processing Record 20 of Set 13 | grindavik
# Processing Record 21 of Set 13 | dawei
# Processing Record 22 of Set 13 | nabire
# Processing Record 23 of Set 13 | san miguel
# Processing Record 24 of Set 13 | acapulco
# Processing Record 25 of Set 13 | moindou
# Processing Record 26 of Set 13 | guerrero negro
# Processing Record 27 of Set 13 | yumen
# Processing Record 28 of Set 13 | ca mau
# Processing Record 29 of Set 13 | boende
# Processing Record 30 of Set 13 | aljezur
# Processing Record 31 of Set 13 | nileshwar
# Processing Record 32 of Set 13 | swan hill
# Processing Record 33 of Set 13 | gayny
# Processing Record 34 of Set 13 | yarkovo
# Processing Record 35 of Set 13 | manoel urbano
# Processing Record 36 of Set 13 | loralai
# Processing Record 37 of Set 13 | bozeman
# Processing Record 38 of Set 13 | mae hong son
# Processing Record 39 of Set 13 | sola
# Processing Record 40 of Set 13 | witu
# Processing Record 41 of Set 13 | mumford
# Processing Record 42 of Set 13 | tupelo
# Processing Record 43 of Set 13 | shakawe
# Processing Record 44 of Set 13 | valparaiso
# Processing Record 45 of Set 13 | roma
# Processing Record 46 of Set 13 | riohacha
# Processing Record 47 of Set 13 | kozhva
# Processing Record 48 of Set 13 | berdigestyakh
# Processing Record 49 of Set 13 | sid
# Processing Record 50 of Set 13 | agadez
# Processing Record 1 of Set 14 | dryden
# Processing Record 2 of Set 14 | dallas
# Processing Record 3 of Set 14 | doctor pedro p. pena
# City not found. Skipping
# Processing Record 4 of Set 14 | travagliato
# Processing Record 5 of Set 14 | rio gallegos
# Processing Record 6 of Set 14 | la rochelle
# Processing Record 7 of Set 14 | hami
# Processing Record 8 of Set 14 | texarkana
# Processing Record 9 of Set 14 | eenhana
# Processing Record 10 of Set 14 | antofagasta
# Processing Record 11 of Set 14 | komsomolskiy
# Processing Record 12 of Set 14 | kisangani
# Processing Record 13 of Set 14 | chilca
# Processing Record 14 of Set 14 | seoul
# Processing Record 15 of Set 14 | nakhon phanom
# Processing Record 16 of Set 14 | maniitsoq
# Processing Record 17 of Set 14 | anadyr
# Processing Record 18 of Set 14 | charlestown
# Processing Record 19 of Set 14 | cayhagan
# Processing Record 20 of Set 14 | kayerkan
# Processing Record 21 of Set 14 | skibbereen
# Processing Record 22 of Set 14 | acari
# Processing Record 23 of Set 14 | hamilton
# Processing Record 24 of Set 14 | cockburn town
# Processing Record 25 of Set 14 | aanekoski
# Processing Record 26 of Set 14 | plettenberg bay
# Processing Record 27 of Set 14 | bacuit
# City not found. Skipping
# Processing Record 28 of Set 14 | bafata
# Processing Record 29 of Set 14 | palana
# Processing Record 30 of Set 14 | nicoya
# Processing Record 31 of Set 14 | korba
# Processing Record 32 of Set 14 | rabo de peixe
# Processing Record 33 of Set 14 | lagoa
# Processing Record 34 of Set 14 | tarko-sale
# Processing Record 35 of Set 14 | guane
# Processing Record 36 of Set 14 | evensk
# Processing Record 37 of Set 14 | moyale
# Processing Record 38 of Set 14 | usinsk
# Processing Record 39 of Set 14 | tutoia
# Processing Record 40 of Set 14 | tual
# Processing Record 41 of Set 14 | vagamo
# Processing Record 42 of Set 14 | tsaratanana
# Processing Record 43 of Set 14 | vaitape
# Processing Record 44 of Set 14 | asilah
# Processing Record 45 of Set 14 | puerto escondido
# Processing Record 46 of Set 14 | sinkat
# City not found. Skipping
# Processing Record 47 of Set 14 | syasstroy
# Processing Record 48 of Set 14 | san jeronimo
# Processing Record 49 of Set 14 | bukama
# Processing Record 50 of Set 14 | monroe
# Processing Record 1 of Set 15 | necochea
# Processing Record 2 of Set 15 | peniche
# Processing Record 3 of Set 15 | nanga eboko
# Processing Record 4 of Set 15 | vila
# Processing Record 5 of Set 15 | wewak
# Processing Record 6 of Set 15 | tecoanapa
# Processing Record 7 of Set 15 | vicksburg
# Processing Record 8 of Set 15 | syracuse
# Processing Record 9 of Set 15 | conceicao do araguaia
# Processing Record 10 of Set 15 | jiroft
# City not found. Skipping
# Processing Record 11 of Set 15 | huarmey
# Processing Record 12 of Set 15 | ugoofaaru
# Processing Record 13 of Set 15 | cessnock
# Processing Record 14 of Set 15 | veraval
# Processing Record 15 of Set 15 | thinadhoo
# Processing Record 16 of Set 15 | kralendijk
# Processing Record 17 of Set 15 | yaounde
# Processing Record 18 of Set 15 | geresk
# City not found. Skipping
# Processing Record 19 of Set 15 | banmo
# City not found. Skipping
# Processing Record 20 of Set 15 | labuhan
# Processing Record 21 of Set 15 | rongcheng
# Processing Record 22 of Set 15 | yiyang
# Processing Record 23 of Set 15 | bay roberts
# Processing Record 24 of Set 15 | praya
# Processing Record 25 of Set 15 | port macquarie
# Processing Record 26 of Set 15 | menongue
# Processing Record 27 of Set 15 | enshi
# Processing Record 28 of Set 15 | pocerski pricinovic
# Processing Record 29 of Set 15 | kudahuvadhoo
# Processing Record 30 of Set 15 | kiruna
# Processing Record 31 of Set 15 | mongo
# Processing Record 32 of Set 15 | malatya
# Processing Record 33 of Set 15 | chiang rai
# Processing Record 34 of Set 15 | baraya
# Processing Record 35 of Set 15 | manokwari
# Processing Record 36 of Set 15 | pathein
# Processing Record 37 of Set 15 | scottsburgh
# City not found. Skipping
# Processing Record 38 of Set 15 | anloga
# Processing Record 39 of Set 15 | say
# Processing Record 40 of Set 15 | saint-georges
# Processing Record 41 of Set 15 | oyama
# Processing Record 42 of Set 15 | bahia honda
# Processing Record 43 of Set 15 | skjervoy
# Processing Record 44 of Set 15 | aranos
# Processing Record 45 of Set 15 | harper
# Processing Record 46 of Set 15 | mnogovershinnyy
# Processing Record 47 of Set 15 | zlitan
# Processing Record 48 of Set 15 | verkhnevilyuysk
# Processing Record 49 of Set 15 | boras
# Processing Record 50 of Set 15 | najran
# Processing Record 1 of Set 16 | cairns
# Processing Record 2 of Set 16 | quelimane
# Processing Record 3 of Set 16 | ochakiv
# Processing Record 4 of Set 16 | afmadu
# City not found. Skipping
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 700

# %%
# Add the data to a list in a dict then at the DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0  Port Elizabeth      ZA  2021-09-24 20:05:07 -33.9180   25.5701     54.10
# 1       Busselton      AU  2021-09-24 20:05:07 -33.6500  115.3333     47.05
# 2       Mahebourg      MU  2021-09-24 20:05:08 -20.4081   57.7000     71.26
# 3         Ushuaia      AR  2021-09-24 20:05:08 -54.8000  -68.3000     42.46
# 4        Klaksvik      FO  2021-09-24 20:05:09  62.2266   -6.5890     43.72
# 5        Tasiilaq      GL  2021-09-24 20:05:10  65.6145  -37.6368     37.56
# 6          Atuona      PF  2021-09-24 20:05:10  -9.8000 -139.0333     77.49
# 7   Zelenoborskiy      RU  2021-09-24 20:05:10  66.8450   32.3622     45.86
# 8      Irtyshskiy      RU  2021-09-24 20:05:11  58.3333   68.1333     39.11
# 9          Avarua      CK  2021-09-24 20:01:35 -21.2078 -159.7750     75.25
#
#    Humidity  Cloudiness  Wind Speed      Current Description
# 0        88          40        1.45         scattered clouds
# 1        76          11       14.81               few clouds
# 2        79           4       15.48                clear sky
# 3        87          75       13.80  heavy intensity drizzle
# 4        68          95       11.41          overcast clouds
# 5        88          93        4.70          overcast clouds
# 6        78          52       18.14            broken clouds
# 7        98         100        7.56          overcast clouds
# 8        89           8        2.62                clear sky
# 9        60          99       11.50          overcast clouds

# %%
# Create CSV file of DF
csv_weather_file = "WeatherPy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
